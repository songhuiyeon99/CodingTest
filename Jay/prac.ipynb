# %%
def print_stars(n):
  lists=[]
  if n==1:
    return '*'
  else:
    Stars=print_stars(n//3)
    for star in Stars:
      lists.append(star*3)
    for star in Stars:
      lists.append(star+' '*(n//3)+star)
    for star in Stars:
      lists.append(star*3)
  return lists

# %%
n=int(input())
for item in print_stars(n):
  print(item)
